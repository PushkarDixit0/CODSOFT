# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df= pd.read_csv('/content/car_purchasing.csv' , encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns = ["customer name","customer e-mail","country","gender"],axis = 1,inplace = True)

# %%
X = df.drop("car purchase amount",axis = 1)
Y = df["car purchase amount"]

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
Y = scaler.fit_transform(Y.values.reshape(-1,1))

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = Sequential()

model.add(Dense(10,activation = 'relu',input_dim=4))
model.add(Dense(10,activation = 'relu'))
model.add(Dense(1,activation = 'linear'))

model.compile(optimizer = 'adam',loss = "mean_squared_error",metrics=["mean_absolute_error"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train,y_train,epochs = 50 , validation_split = 0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 16ms/step - loss: 0.9195 - mean_absolute_error: 0.9311 - val_loss: 0.7680 - val_mean_absolute_error: 0.8558
# Epoch 2/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7394 - mean_absolute_error: 0.8331 - val_loss: 0.6165 - val_mean_absolute_error: 0.7642
# Epoch 3/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5972 - mean_absolute_error: 0.7448 - val_loss: 0.4910 - val_mean_absolute_error: 0.6791
# Epoch 4/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4772 - mean_absolute_error: 0.6623 - val_loss: 0.3882 - val_mean_absolute_error: 0.6006
# Epoch 5/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3781 - mean_absolute_error: 0.5859 - val_loss: 0.3023 - val_mean_absolute_error: 0.5261
# Epoch 6/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2961 - mean_absolute_error: 0.5134 - val_loss: 0.2300 - val_mean_absolute_error: 0.4550
# Epoch 7/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2251 - mean_absolute_error: 0.4443 - val_loss: 0.1716 - val_mean_absolute_error: 0.3887
# Epoch 8/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1692 - mean_absolute_error: 0.3791 - val_loss: 0.1238 - val_mean_absolute_error: 0.3244
# Epoch 9/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1237 - mean_absolute_error: 0.3170 - val_loss: 0.0863 - val_mean_absolute_error: 0.2642
# Epoch 10/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0874 - mean_absolute_error: 0.2594 - val_loss: 0.0586 - val_mean_absolute_error: 0.2115
# Epoch 11/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0615 - mean_absolute_error: 0.2108 - val_loss: 0.0389 - val_mean_absolute_error: 0.1645
# Epoch 12/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0422 - mean_absolute_error: 0.1702 - val_loss: 0.0264 - val_mean_absolute_error: 0.1292
# Epoch 13/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0303 - mean_absolute_error: 0.1416 - val_loss: 0.0190 - val_mean_absolute_error: 0.1053
# Epoch 14/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_absolute_error: 0.1207 - val_loss: 0.0146 - val_mean_absolute_error: 0.0914
# Epoch 15/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0181 - mean_absolute_error: 0.1060 - val_loss: 0.0117 - val_mean_absolute_error: 0.0816
# Epoch 16/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0151 - mean_absolute_error: 0.0964 - val_loss: 0.0101 - val_mean_absolute_error: 0.0766
# Epoch 17/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0895 - val_loss: 0.0092 - val_mean_absolute_error: 0.0730
# Epoch 18/50
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0119 - mean_absolute_error: 0.0853 - val_loss: 0.0084 - val_mean_absolute_error: 0.0697
# Epoch 19/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0108 - mean_absolute_error: 0.0814 - val_loss: 0.0076 - val_mean_absolute_error: 0.0660
# Epoch 20/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0100 - mean_absolute_error: 0.0779 - val_loss: 0.0071 - val_mean_absolute_error: 0.0637
# Epoch 21/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - mean_absolute_error: 0.0746 - val_loss: 0.0064 - val_mean_absolute_error: 0.0604
# Epoch 22/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0715 - val_loss: 0.0059 - val_mean_absolute_error: 0.0576
# Epoch 23/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0078 - mean_absolute_error: 0.0685 - val_loss: 0.0054 - val_mean_absolute_error: 0.0549
# Epoch 24/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0655 - val_loss: 0.0049 - val_mean_absolute_error: 0.0525
# Epoch 25/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0066 - mean_absolute_error: 0.0629 - val_loss: 0.0044 - val_mean_absolute_error: 0.0487
# Epoch 26/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061 - mean_absolute_error: 0.0598 - val_loss: 0.0039 - val_mean_absolute_error: 0.0453
# Epoch 27/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0055 - mean_absolute_error: 0.0568 - val_loss: 0.0037 - val_mean_absolute_error: 0.0441
# Epoch 28/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0051 - mean_absolute_error: 0.0542 - val_loss: 0.0033 - val_mean_absolute_error: 0.0406
# Epoch 29/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0515 - val_loss: 0.0030 - val_mean_absolute_error: 0.0387
# Epoch 30/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_absolute_error: 0.0491 - val_loss: 0.0028 - val_mean_absolute_error: 0.0371
# Epoch 31/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0039 - mean_absolute_error: 0.0471 - val_loss: 0.0025 - val_mean_absolute_error: 0.0354
# Epoch 32/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0036 - mean_absolute_error: 0.0452 - val_loss: 0.0023 - val_mean_absolute_error: 0.0342
# Epoch 33/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_absolute_error: 0.0436 - val_loss: 0.0022 - val_mean_absolute_error: 0.0329
# Epoch 34/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0423 - val_loss: 0.0020 - val_mean_absolute_error: 0.0319
# Epoch 35/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0029 - mean_absolute_error: 0.0405 - val_loss: 0.0019 - val_mean_absolute_error: 0.0310
# Epoch 36/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0027 - mean_absolute_error: 0.0390 - val_loss: 0.0017 - val_mean_absolute_error: 0.0298
# Epoch 37/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0025 - mean_absolute_error: 0.0378 - val_loss: 0.0016 - val_mean_absolute_error: 0.0289
# Epoch 38/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0362 - val_loss: 0.0015 - val_mean_absolute_error: 0.0279
# Epoch 39/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0348 - val_loss: 0.0014 - val_mean_absolute_error: 0.0270
# Epoch 40/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0339 - val_loss: 0.0013 - val_mean_absolute_error: 0.0261
# Epoch 41/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0019 - mean_absolute_error: 0.0322 - val_loss: 0.0013 - val_mean_absolute_error: 0.0255
# Epoch 42/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0311 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 43/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0298 - val_loss: 0.0011 - val_mean_absolute_error: 0.0237
# Epoch 44/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0287 - val_loss: 0.0010 - val_mean_absolute_error: 0.0229
# Epoch 45/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0014 - mean_absolute_error: 0.0274 - val_loss: 9.4021e-04 - val_mean_absolute_error: 0.0221
# Epoch 46/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0265 - val_loss: 8.7845e-04 - val_mean_absolute_error: 0.0215
# Epoch 47/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0251 - val_loss: 8.2717e-04 - val_mean_absolute_error: 0.0209
# Epoch 48/50
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 7.6672e-04 - val_mean_absolute_error: 0.0201
# Epoch 49/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0237 - val_loss: 7.1812e-04 - val_mean_absolute_error: 0.0195
# Epoch 50/50
# 10/10 [==============================] - 0s 5ms/step - loss: 9.7236e-04 - mean_absolute_error: 0.0224 - val_loss: 6.7536e-04 - val_mean_absolute_error: 0.0189

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
y_pred = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.9748595702718034
